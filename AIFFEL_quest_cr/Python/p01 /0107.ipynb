# %% [markdown]
# <a href="https://colab.research.google.com/github/Eugene3601/AIFFEL_quest_cr/blob/main/AIFFEL_quest_cr/Python/p01%20/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
#형태변환
num = int(float('2.5'))
print(num)
#비교연산
print(5>2)
print(5==2)
print(5!=2)
print(3<5 and 7<5)
print('c' in 'cat')
#불리안 : bool - 값이 있으면 true 없으면 false, 참이면 true 거짓이면 false
print(bool(a))
print(bool(None))

#파이썬 자료형(1)
#정수형(int), 실수형(float)
type(5)
#복합 대입 연산자 : a += 1 --> a에다가 1을 더한거를 다시 대입해라

#문자형(str) - 이스케이프 코드(Escape Sequence)  ex) \n 줄바꿈, \' 작은 따옴표, \" 큰 따옴표, \\ 문자, \t 문자열 사이에 탭 간격줄때, 행끝+\ 이전줄과 이후 줄이 하나의 문자열로 정의
#예시
tabline = 'hello\tpython'
print(tabline)
len(tabline)

num = \
13*1 +\
13*2 +\
13*3 +\
13*4
print(num)

#indexing - 0부터 시작
a= 'python'
a[2]

#slicing : 문자열 일부 가져오기, [n부터 N(인덱스는 N-1)까지 출력; [n:N]]
slicing = 'hello aiffel'
slicing[:5]

num = '123456789'
print(num[::]) #전체 출력
print(num[::2]) #전체를 2 간격으로 출력
print(num[1:8:2]) # 인덱스 1번부터 7번까지 2 간격으로 출력
num[-8:-1:3] #뒤에서부터 세는 음수 인덱스도 활용할 수 있습니다.

#리스트랑 튜플 : 리스트는 편집 가능, 튜플은 편집 불가능
a = [0,1,2] #리스트
b = (1,2,3) #튜플
c = 3,4,5 #튜플, 괄호 생략 가능

#집합(set) : |(합집합), &(교집합), 차집합(a-b), 배타적 차집합(합집합에서 교집합 뺀거, a^b)

#딕셔너리(Dictionary) : 키(key)와 값(value)의 쌍을 저장하는 대용량의 자료구조
dic = {'apple':'사과', 'orange':'오렌지'}


# 실습퀴즈
# 10을 4로 나눈 나머지 값이 c에 할당되도록 하는 복합 대입 연산자를 작성하세요.
c = 10
c %= 4
print(c)  # 2가 출력 되어야 합니다.

# 인덱싱의 값이 ('o', '\t', 'p')으로 나올 수 있도록 문자열 c를 인덱싱해 보고
c = 'hello\tpython'
result = (c[4], c[5], c[6])  # 'o'는 인덱스 4, '\t'는 인덱스 5, 'p'는 인덱스 6
print(result)

# 뒤에서부터 인덱싱을 하여 ('n', 'p', 'e')를 출력할 수 있는 코드를 작성해주세요.
c = 'hello\tpython'
result = (c[-1], c[-6], c[-11])
print(result)

# 아이펠의 몸무게 정보를 지워주세요.
quiz_dic = {'이름':'아이펠', '나이':35, 'MBTI':'ESFJ','몸무게':80}
del quiz_dic['몸무게']
quiz_dic

###파이썬2###
# 변수
a = 'Hello'
b =  10
a,b = b,a
a
b

a = Eugene
a

#반복문
#While + 조건문 : 조건문을 만족하는 동안
#1-10까지 출력하는 코드를 whihle문으로
num = 1
while num <= 10 :
    print(num)
    num += 1 #11이되면 10을 넘으니까 안됨.


#break
a=0
while a < 10:
    a += 1
    if a % 2 ==0: #짟수
        break
    print(a)

#Continue
a=0
while a < 10:
    a += 1
    if a % 2 ==0: #짟수
        continue
    print(a)

#for문과 range 함수
#리스트로 반복문 만들기
a = [1,2,3]
for i in a:
    print(i, '번 출력')

#문자열로 반복문 만들기
a = 'aiffel'
for i in a:
    print(i)
#다양한 반복문 활용
a =[('apple', '사과'), ('banana', '바나나'), ('melon', '멜론')]
for (en, ko) in a :
    print(en, '는 한국어로', ko, '입니다')

#range (시작, 끝+1, 증가) //6이면 5까지 출력됨)
for i in range (6):
    print(i)


# 꽈배기가 품절일 때
korean_pretzel = 10
while korean_pretzel:
    print('꽈배기 ', korean_pretzel, '개 있습니다.')
    order = int(input('주문 개수 : 6'))
    korean_pretzel -= order
    print('남은 꽈배기는 ', korean_pretzel, '개 입니다.')
    print('*'*25)
    if korean_pretzel <= 0:
        print('꽈배기 품절입니다.')
        break

# for문을 사용해 구구단 출력하기
# Q. n * x = m 형태로 반복해서 출력되도록 구현해보세요!
n = int(input("원하는 단수를 입력하세요: "))  # 사용자에게 단수를 입력받음
for x in range(1, 10):  # 1부터 9까지 반복
    print(str(n) + " * " + str(x) + " = " + str(n * x))  # 구구단 출력

#if -> elif -> else
money = int(input('현재 수중에 있는 돈은 얼마인가요?'))
if money >= 16000:
    print('택시도 타고, 커피도 마신다.')
elif money >= 12000:
    print('커피는 포기하고 택시를 탄다.')
elif money >= 5300:
    print('커피를 마시고 버스에 탄다.')
else:
    print('목이 마르지만 참고 버스를 탄다.')

#함수 def
# 간단한 함수를 통해 매개변수와 인수의 차이를 느껴 보세요.
def add(a, b):    # a, b는 매개변수
    return a + b

add(1, 2)  # 1, 2는 인수

#인수의 형식
#위치인수(positional argument)
def print_nums(a, b, c):
    print(c)
    print(b)
    print(a)

a = [10, 20, 30]
print_nums(*a)

#가변인수
# 가변 인수의 예
def sum_nums(*args):
    sum = 0
    for arg in args:
        sum += arg
    return sum

sum_nums(1, 2, 3)

# 키워드 인수의 예
def dog_info(name, age, breed):
    print('이름 :', name)
    print('나이 :', age)
    print('품종 :', breed)
dog_info(age=10, breed='진돗개', name='규봉이')

# 키워드 가변 인수 함수의 예
def dog_info(**kwargs):
    for kword, arg in kwargs.items():  # 딕셔너리 쌍을 얻는 items() 함수
        print(kword, ':', arg)
dog_info(name='규봉이')  # 인수가 1개
dog_info(name='규봉이', age=10, gender='male')  # 인수가 3개
# 딕셔너리 언팩킹
a = {'name':'규봉이', 'age':10, 'breed':'진돗개', 'gender':'male'}

# 실습퀴즈2. 반복문
# while문으로 구구단 13단을 만들어 보세요.

num = 1

while num <=9:                  # 조건을 적어주세요.
    answer = 13 * num
    print(13, 'X', num, '=', answer)
    num +=1

# 실습퀴즈7. 함수
# 나만의 프로필 함수를 만들어 보세요.

def my_profile(**kwargs):  # 키워드 가변 인수 활용
    print('저를 소개합니다.')
    for key, value in kwargs.items():  # 키와 값을 순회하며 출력
        print(f"{key}: {value}")

me = {'name': '황유진', 'age': 27, 'MBTI': 'ESTJ'}

my_profile(**me)  # 키워드 가변 인수를 활용해 딕셔너리 전달
